# %%
import pandas as pd

# %%
df = pd.read_csv('Hashrate.csv')

# %%
df['date']= pd.to_datetime(df['date'])
df.set_index('date', inplace=True)
df
# Out:
#                        country monthly_hashrate_%  \
# date
# 2019-09-01      Mainland China             75.53%
# 2019-09-01               Other               6.1%
# 2019-09-01  Russian Federation              5.93%
# 2019-09-01       United States              4.06%
# 2019-09-01            Malaysia              3.25%
# ...                        ...                ...
# 2022-01-01  Russian Federation              4.66%
# 2022-01-01           Germany *              3.06%
# 2022-01-01            Malaysia              2.51%
# 2022-01-01           Ireland *              1.97%
# 2022-01-01  Iran, Islamic Rep.              0.12%
#
#             monthly_absolute_hashrate_EH/S
# date
# 2019-09-01                           66.76
# 2019-09-01                            5.39
# 2019-09-01                            5.24
# 2019-09-01                            3.59
# 2019-09-01                            2.88
# ...                                    ...
# ...

# %%
df['country'].value_counts()
# Out:
# Mainland China        29
# Other                 29
# Russian Federation    29
# United States         29
# Malaysia              29
# Iran, Islamic Rep.    29
# Kazakhstan            29
# Canada                29
# Germany *             29
# Ireland *             29
# Name: country, dtype: int64

# %%
hashrate_us = df.loc[df['country']=='United States']
hashrate_us
# Out:
#                   country monthly_hashrate_%  monthly_absolute_hashrate_EH/S
# date
# 2019-09-01  United States              4.06%                            3.59
# 2019-10-01  United States              5.58%                            5.30
# 2019-11-01  United States              6.58%                            6.02
# 2019-12-01  United States              3.87%                            3.69
# 2020-01-01  United States              3.44%                            3.76
# 2020-02-01  United States              4.54%                            5.02
# 2020-03-01  United States              7.07%                            7.55
# 2020-04-01  United States              7.24%                            8.07
# 2020-05-01  United States              8.22%                            8.69
# 2020-06-01  United States               6.7%                            7.47
# 2020-07-01  United States              5.09%                            6.22
# ...

# %%
hashrate_us.plot(kind='line',figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
hashrate_china = df.loc[df['country']=='Mainland China']
hashrate_china
# Out:
#                    country monthly_hashrate_%  monthly_absolute_hashrate_EH/S
# date
# 2019-09-01  Mainland China             75.53%                           66.76
# 2019-10-01  Mainland China             74.78%                           71.03
# 2019-11-01  Mainland China             72.33%                           66.21
# 2019-12-01  Mainland China             73.46%                           70.06
# 2020-01-01  Mainland China             72.69%                           79.41
# 2020-02-01  Mainland China             72.98%                           80.59
# 2020-03-01  Mainland China             67.06%                           71.65
# 2020-04-01  Mainland China             64.81%                           72.19
# 2020-05-01  Mainland China             59.48%                           62.89
# 2020-06-01  Mainland China             64.67%                           72.19
# 2020-07-01  Mainland China             66.86%                           81.71
# ...

# %%
hashrate_china.plot(kind='line',figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
hashrate_russia = df.loc[df['country']=='Russian Federation']
hashrate_russia
# Out:
#                        country monthly_hashrate_%  \
# date
# 2019-09-01  Russian Federation              5.93%
# 2019-10-01  Russian Federation              5.87%
# 2019-11-01  Russian Federation              6.24%
# 2019-12-01  Russian Federation              6.23%
# 2020-01-01  Russian Federation              6.05%
# 2020-02-01  Russian Federation              5.56%
# 2020-03-01  Russian Federation              5.97%
# 2020-04-01  Russian Federation               6.9%
# 2020-05-01  Russian Federation              9.34%
# 2020-06-01  Russian Federation              8.25%
# 2020-07-01  Russian Federation              8.08%
# 2020-08-01  Russian Federation              8.17%
# 2020-09-01  Russian Federation              5.74%
# 2020-10-01  Russian Federation               4.9%
# 2020-11-01  Russian Federation              6.77%
# 2020-12-01  Russian Federation              7.16%
# 2021-01-01  Russian Federation              6.91%
# 2021-02-01  Russian Federation              6.43%
# ...

# %%
hashrate_russia.plot(kind='line',figsize=(14,6))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
hashrate_canada = df.loc[df['country']=='Canada']
hashrate_canada
# Out:
#            country monthly_hashrate_%  monthly_absolute_hashrate_EH/S
# date
# 2019-09-01  Canada              1.06%                            0.94
# 2019-10-01  Canada              0.65%                            0.61
# 2019-11-01  Canada              0.87%                            0.79
# 2019-12-01  Canada              1.03%                            0.98
# 2020-01-01  Canada              1.06%                            1.16
# 2020-02-01  Canada              0.92%                            1.02
# 2020-03-01  Canada              0.79%                            0.85
# 2020-04-01  Canada              0.82%                            0.91
# 2020-05-01  Canada              1.02%                            1.08
# 2020-06-01  Canada              0.62%                            0.70
# 2020-07-01  Canada              1.15%                            1.40
# 2020-08-01  Canada              1.87%                            2.32
# ...
